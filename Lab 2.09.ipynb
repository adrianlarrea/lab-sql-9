# %% [markdown]
# ### LAB 2.9.

# %%
import pandas as pd
import numpy as np

import pymysql
from sqlalchemy import create_engine

from getpass import getpass  # To get the password without showing the input

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
# concatenate 3 strings into 1, 
engine = create_engine(connection_string)
# engine is a point to that connection, the engine knows where the database is stored, how to access it

# %% [markdown]
# #### 1.How many distinct (different) actors' last names are there?

# %%
query = 'SELECT * \
FROM actor \
GROUP BY last_name \
HAVING COUNT(last_name)=1'

data = pd.read_sql_query(query, engine)
data.head(10)
# Out:
#    actor_id first_name  last_name         last_update
# 0        76   ANGELINA    ASTAIRE 2006-02-15 04:34:33
# 1       112    RUSSELL     BACALL 2006-02-15 04:34:33
# 2       115   HARRISON       BALE 2006-02-15 04:34:33
# 3       187      RENEE       BALL 2006-02-15 04:34:33
# 4        47      JULIA  BARRYMORE 2006-02-15 04:34:33
# 5       158     VIVIEN   BASINGER 2006-02-15 04:34:33
# 6        14     VIVIEN     BERGEN 2006-02-15 04:34:33
# 7       121       LIZA    BERGMAN 2006-02-15 04:34:33
# 8       189       CUBA      BIRCH 2006-02-15 04:34:33
# 9        25      KEVIN      BLOOM 2006-02-15 04:34:33

# %% [markdown]
# #### 2.Add an additional column day_type with values 'weekend' and 'workday' depending on the rental day of the week.

# %%
query = 'SELECT *, \
            CASE \
            WHEN DATE_FORMAT(rental_date,"%%a") = "Sat" then "Weekend" \
            WHEN DATE_FORMAT(rental_date,"%%a") = "Sun" then "Weekend" \
            ELSE "Weekday" \
            END AS "column_day_type" \
        FROM sakila.rental'

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    rental_id         rental_date  inventory_id  customer_id  \
# 0          1 2005-05-24 22:53:30           367          130
# 1          2 2005-05-24 22:54:33          1525          459
# 2          3 2005-05-24 23:03:39          1711          408
# 3          4 2005-05-24 23:04:41          2452          333
# 4          5 2005-05-24 23:05:21          2079          222
#
#           return_date  staff_id         last_update column_day_type
# 0 2005-05-26 22:04:30         1 2006-02-15 21:30:53         Weekday
# 1 2005-05-28 19:40:33         1 2006-02-15 21:30:53         Weekday
# 2 2005-06-01 22:12:39         1 2006-02-15 21:30:53         Weekday
# 3 2005-06-03 01:43:41         2 2006-02-15 21:30:53         Weekday
# 4 2005-06-02 04:33:21         1 2006-02-15 21:30:53         Weekday

# %% [markdown]
# #### 3.Get all films with ARMAGEDDON in the title.

# %%
query = 'SELECT *\
FROM film \
WHERE title LIKE "%%ARMAGEDDON%%"  '

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    film_id                  title  \
# 0       39        ARMAGEDDON LOST
# 1      507    LADYBUGS ARMAGEDDON
# 2      571       METAL ARMAGEDDON
# 3      598    MOSQUITO ARMAGEDDON
# 4      838  STAGECOACH ARMAGEDDON
#
#                                          description  release_year  \
# 0  A Fast-Paced Tale of a Boat And a Teacher who ...          2006
# 1  A Fateful Reflection of a Dog And a Mad Scient...          2006
# 2  A Thrilling Display of a Lumberjack And a Croc...          2006
# 3  A Thoughtful Character Study of a Waitress And...          2006
# 4  A Touching Display of a Pioneer And a Butler w...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                5         0.99      99
# 1            1                 None                4         0.99     113
# 2            1                 None                6         2.99     161
# 3            1                 None                6         0.99      57
# 4            1                 None                5         4.99     112
#
#    replacement_cost rating                      special_features  \
# 0             10.99      G                              Trailers
# 1             13.99  NC-17                        Deleted Scenes
# 2             26.99  PG-13  Trailers,Commentaries,Deleted Scenes
# 3             22.99      G                              Trailers
# 4             25.99      R               Trailers,Deleted Scenes
#
#           last_update
# 0 2006-02-15 05:03:42
# 1 2006-02-15 05:03:42
# 2 2006-02-15 05:03:42
# 3 2006-02-15 05:03:42
# 4 2006-02-15 05:03:42

# %% [markdown]
# #### 4.Get 10 the longest films.

# %%
query = 'SELECT title \
FROM film \
ORDER BY length desc \
LIMIT 10'

data = pd.read_sql_query(query, engine)
data.head(10)
# Out:
#                 title
# 0      DARN FORRESTER
# 1        POND SEATTLE
# 2       CHICAGO NORTH
# 3       MUSCLE BRIGHT
# 4        WORST BANGER
# 5         GANGS PRIDE
# 6  SOLDIERS EVOLUTION
# 7           HOME PITY
# 8   SWEET BROTHERHOOD
# 9      CONTROL ANTHEM

# %% [markdown]
# #### 5.How many films include Behind the Scenes content?

# %%
query = 'SELECT COUNT(title) \
FROM film \
WHERE special_features LIKE "%%Behind the Scenes%%"'

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    COUNT(title)
# 0           538

# %% [markdown]
# #### 6.Which kind of movies (rating) have a mean duration of more than two hours?

# %%
query = 'SELECT rating, AVG(length) \
FROM sakila.film \
GROUP BY rating \
HAVING AVG(length) > 120'

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#   rating  AVG(length)
# 0  PG-13     120.4439

# %% [markdown]
# #### 7.Rank films by length (filter out the rows that have nulls or 0s in length column). In your output, only select the columns title, length, and the rank.

# %%
query = 'SELECT title, length, \
          CASE \
          WHEN length < 92 then "Shorty" \
          WHEN length >= 92 and length < 138 then "Medium" \
          WHEN length >= 138 then "Long" \
          ELSE "No status" \
          END AS "rank" \
        FROM film \
        WHERE length <> " " or length <> null \
        ORDER BY length ASC'

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#                  title  length    rank
# 0         ALIEN CENTER      46  Shorty
# 1            IRON MOON      46  Shorty
# 2        KWAI HOMEWARD      46  Shorty
# 3     LABYRINTH LEAGUE      46  Shorty
# 4  RIDGEMONT SUBMARINE      46  Shorty
